# %% [markdown]
# TASK 1 : Analyze social media data to understand user behavior and
# engagement

# %% [markdown]
# STATEMENT : Embark on a comprehensive analysis of social media data to gain insights into user
# behavior and engagement. The project aims to understand how users interact with
# content, identify patterns, and derive actionable insights for improving social media
# strategies.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
import seaborn as sns
from pandas import read_csv
from matplotlib import pyplot
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# About the dataset
#
# The dataset has 11 variables describing each person's Twiiter Activity.
#
# These variables are:
#
# Follower Count: Number of followers of the person on Twitter
#
# Follwoing Count: Number of Twitter users the person follows
#
# Listed Count: Number of people that have added the person to a list
#
# Mentions Received: Number of times people have mentioned (@) the person
#
# Retweets Received: Number of times a tweet was retweeted
#
# Mentions Sent: Number of times the person mentioned (@) someone
#
# Retweets Sent: Number of times the person retweet a tweet
#
# Posts: Number of posts
#
# Network Feature 1, 2, 3: Local follower network of the person

# %% [markdown]
# Loadind dataset

# %%
Twitter_Train = pd.read_csv("/content/test (1).csv")
Twitter_Train
# Out:
#       A_follower_count  A_following_count  A_listed_count  \
# 0               614689                400            5729
# 1               739581              10723            1279
# 2                 3638               3341              85
# 3                  613               1259              31
# 4              1352348                331           15647
# ...                ...                ...             ...
# 5947            614689                400            5729
# 5948              3764                703             222
# 5949           1611042                936           10346
# 5950            631958                674            7522
# 5951           2307845                329           12580
#
#       A_mentions_received  A_retweets_received  A_mentions_sent  \
# 0              199.618296            67.812469         9.366192
# 1              102.026750            96.771319         1.537322
# 2                2.793577             1.402703         2.594089
# 3                1.326041             0.356943         6.249678
# 4            19129.848662         14552.733991         2.065418
# ...                   ...                  ...              ...
# 5947           199.618296            67.812469         9.366192
# 5948             5.270621             1.601159         2.338333
# 5949           388.093282            65.719046         2.086961
# 5950           614.968745           329.330091         4.052279
# 5951           530.084862           189.947739         4.827720
#
#       A_retweets_sent    A_posts  A_network_feature_1  A_network_feature_2  \
# 0            0.359534   4.094488                  669            39.193741
# 1            1.054358   3.467754                  432            11.191686
# 2            0.598150   3.802143                   11             9.416667
# 3            2.323064   7.488116                    4             5.000000
# 4            0.580955  16.281502                52580             3.092448
# ...               ...        ...                  ...                  ...
# 5947         0.359534   4.094488                  669            39.193741
# 5948         0.100503   1.596539                   18           139.444444
# 5949         0.349327   1.096322                 1637            35.500603
# 5950         1.340566  12.305035                 2536            35.838659
# 5951         0.100503   3.130447                 2164            80.914768
#
#       ...  B_following_count  B_listed_count  B_mentions_received  \
# 0     ...                563           20057           967.720642
# 1     ...              12949            1311            38.260522
# 2     ...                320            3673          1207.190077
# 3     ...               3599            1072            10.300222
# 4     ...             147521           15043          9902.070379
# ...   ...                ...             ...                  ...
# 5947  ...             550744           20006           936.636126
# 5948  ...               3557               9             0.751434
# 5949  ...                140           13838           133.213345
# 5950  ...               2799            7371           296.978205
# 5951  ...                240           39725          1404.436304
#
#       B_retweets_received  B_mentions_sent  B_retweets_sent     B_posts  \
# 0              579.431128         4.473798         0.805680    6.241806
# 1               10.697567        12.845793         1.584284   12.106662
# 2              599.721600         0.842022         0.593199    7.044735
# 3                3.828561         1.624092         0.100503    1.614287
# 4             5012.055876        10.438460         0.100503  193.072418
# ...                   ...              ...              ...         ...
# 5947           206.101772        41.317189         0.595962   42.813704
# 5948             0.295998         0.100503         0.100503    0.100503
# 5949            56.027747         2.622550         1.121160    2.622550
# 5950           135.831429        15.033026         4.807180    8.262063
# 5951           431.103945         2.596749         0.100503    5.559490
#
#       B_network_feature_1  B_network_feature_2  B_network_feature_3
# 0                    4027            57.643839          3201.293706
# 1                     144           209.717241         21496.565517
# 2                    3918             7.859818           637.983300
# 3                      43           113.840909          2537.772727
# 4                   28564            10.964144          1035.955493
# ...                   ...                  ...                  ...
# 5947                 3691            69.150872          3456.096107
# 5948                    3             2.666667           218.333333
# 5949                  562           135.158451          5187.500000
# 5950                 1201            87.183775          3547.782285
# 5951                 5748            75.878553          2812.668562
#
# [5952 rows x 22 columns]

# %% [markdown]
# Exploring the dataset

# %%
df.shape
# Out:
# (29, 1468)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Columns: 1468 entries, Date to Weekly Total web site click count per Page by age and gender - UNKNOWN.U
# dtypes: float64(1266), object(202)
# memory usage: 332.7+ KB

# %%
df.describe()
# Out:
#        Daily Like Sources - feed_story  \
# count                        13.000000
# mean                          3.769231
# std                           6.771925
# min                           1.000000
# 25%                           1.000000
# 50%                           2.000000
# 75%                           3.000000
# max                          26.000000
#
#        Daily Like Sources - page_browser_invite  \
# count                                  2.000000
# mean                                   2.000000
# std                                    1.414214
# min                                    1.000000
# 25%                                    1.500000
# 50%                                    2.000000
# 75%                                    2.500000
# max                                    3.000000
#
#        Daily Like Sources - page_invite_notif_inline_accept  \
# count                                                1.0
# mean                                                 5.0
# std                                                  NaN
# min                                                  5.0
# 25%                                                  5.0
# 50%                                                  5.0
# 75%                                                  5.0
# max                                                  5.0
#
#        Daily Like Sources - page_invite_pending_invite_screen_accept_invite  \
# count                                           6.000000
# mean                                            6.666667
# std                                            11.003030
# min                                             1.000000
# 25%                                             1.250000
# 50%                                             2.500000
# 75%                                             3.750000
# max                                            29.000000
#
#        Daily Like Sources - page_profile  Daily Like Sources - page_timeline  \
# count                          16.000000                            3.000000
# mean                            2.375000                            1.333333
# std                             2.604483                            0.577350
# min                             1.000000                            1.000000
# 25%                             1.000000                            1.000000
# 50%                             1.000000                            1.000000
# 75%                             2.250000                            1.500000
# max                            11.000000                            2.000000
#
#        Daily Like Sources - pagelike_adder_for_reactivated_users  \
# count                                           8.000000
# mean                                            1.125000
# std                                             0.353553
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             2.000000
#
#        Daily Like Sources - profile_edit  \
# count                                1.0
# mean                                 1.0
# std                                  NaN
# min                                  1.0
# 25%                                  1.0
# 50%                                  1.0
# 75%                                  1.0
# max                                  1.0
#
#        Daily Like Sources - reactivated_fan_add  Daily Like Sources - search  \
# count                                       6.0                          1.0
# mean                                        1.0                          2.0
# std                                         0.0                          NaN
# min                                         1.0                          2.0
# 25%                                         1.0                          2.0
# 50%                                         1.0                          2.0
# 75%                                         1.0                          2.0
# max                                         1.0                          2.0
#
#        ...  \
# count  ...
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        Weekly Total web site click count per Page by age and gender - 55-64.U  \
# count                                               28.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Weekly Total web site click count per Page by age and gender - 65+.F  \
# count                                               28.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Weekly Total web site click count per Page by age and gender - 65+.M  \
# count                                               28.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Weekly Total web site click count per Page by age and gender - 65+.U  \
# count                                               28.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Weekly Total web site click count per Page by age and gender - &lt;13.F  \
# count                                               28.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Weekly Total web site click count per Page by age and gender - &lt;13.M  \
# count                                               28.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Weekly Total web site click count per Page by age and gender - &lt;13.U  \
# count                                               28.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Weekly Total web site click count per Page by age and gender - UNKNOWN.F  \
# count                                               28.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Weekly Total web site click count per Page by age and gender - UNKNOWN.M  \
# count                                               28.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Weekly Total web site click count per Page by age and gender - UNKNOWN.U
# count                                               28.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
# [8 rows x 1266 columns]

# %%
df.nunique()
# Out:
# Date                                                                        28
# Lifetime Total Likes                                                        23
# Daily New Likes                                                             13
# Daily Unlikes                                                                6
# Daily Page Engaged Users                                                    27
#                                                                             ..
# Weekly Total web site click count per Page by age and gender - &lt;13.M      1
# Weekly Total web site click count per Page by age and gender - &lt;13.U      1
# Weekly Total web site click count per Page by age and gender - UNKNOWN.F     1
# Weekly Total web site click count per Page by age and gender - UNKNOWN.M     1
# Weekly Total web site click count per Page by age and gender - UNKNOWN.U     1
# Length: 1468, dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Lifetime Total Likes', 'Daily New Likes', 'Daily Unlikes',
#        'Daily Page Engaged Users', 'Weekly Page Engaged Users',
#        '28 Days Page Engaged Users', 'Daily Total Reach', 'Weekly Total Reach',
#        '28 Days Total Reach',
#        ...
#        'Weekly Total web site click count per Page by age and gender - 55-64.U',
#        'Weekly Total web site click count per Page by age and gender - 65+.F',
#        'Weekly Total web site click count per Page by age and gender - 65+.M',
#        'Weekly Total web site click count per Page by age and gender - 65+.U',
#        'Weekly Total web site click count per Page by age and gender - &lt;13.F',
#        'Weekly Total web site click count per Page by age and gender - &lt;13.M',
#        'Weekly Total web site click count per Page by age and gender - &lt;13.U',
#        'Weekly Total web site click count per Page by age and gender - UNKNOWN.F',
#        'Weekly Total web site click count per Page by age and gender - UNKNOWN.M',
#        'Weekly Total web site click count per Page by age and gender - UNKNOWN.U'],
#       dtype='object', length=1468)

# %% [markdown]
# Finding numeric columns

# %% [markdown]
# num_col=[]
# for col in df.columns:
#     if(df[col].dtypes != 'object'):

# %%
num_col=[]
for col in df.columns:
  if(df[col].dtypes != 'object'):
    num_col.append(col)

print(num_col)
# Out:
# ['Daily Like Sources - feed_story', 'Daily Like Sources - page_browser_invite', 'Daily Like Sources - page_invite_notif_inline_accept', 'Daily Like Sources - page_invite_pending_invite_screen_accept_invite', 'Daily Like Sources - page_profile', 'Daily Like Sources - page_timeline', 'Daily Like Sources - pagelike_adder_for_reactivated_users', 'Daily Like Sources - profile_edit', 'Daily Like Sources - reactivated_fan_add', 'Daily Like Sources - search', 'Daily Like Sources - timeline_collection', 'Daily Like Sources - timeline_like_chaining', 'Daily Like Sources - unknown', 'Daily Total Frequency Distribution - 2', 'Daily Total Frequency Distribution - 3', 'Daily Total Frequency Distribution - 4', 'Daily Total Frequency Distribution - 5', 'Daily Total Frequency Distribution - 6-10', 'Daily Total Frequency Distribution - 11-20', 'Daily Total Frequency Distribution - 21+', 'Weekly Total Frequency Distribution - 2', 'Weekly Total Frequency Distribution - 3', 'Weekly Total Frequency Distribution - 4', 'Weekly Total Frequency Distribution - 5', 'Weekly Total Frequency Distribution - 6-10', 'Weekly Total Frequency Distribution - 11-20', 'Weekly Total Frequency Distribution - 21+', '28 Days Total Frequency Distribution - 2', '28 Days Total Frequency Distribution - 3', '28 Days Total Frequency Distribution - 4', '28 Days Total Frequency Distribution - 5', '28 Days Total Frequency Distribution - 6-10', '28 Days Total Frequency Distribution - 11-20', '28 Days Total Frequency Distribution - 21+', 'Daily Page Posts Frequency Distribution - 2', 'Daily Page Posts Frequency Distribution - 3', 'Daily Page Posts Frequency Distribution - 4', 'Daily Page Posts Frequency Distribution - 5', 'Daily Page Posts Frequency Distribution - 6-10', 'Daily Page Posts Frequency Distribution - 11-20', 'Daily Page Posts Frequency Distribution - 21+', 'Weekly Page Posts Frequency Distribution - 2', 'Weekly Page Posts Frequency Distribution - 3', 'Weekly Page Posts Frequency Distribution - 4', 'Weekly Page Posts Frequency Distribution - 5', 'Weekly Page Posts Frequency Distribution - 6-10', 'Weekly Page Posts Frequency Distribution - 11-20', 'Weekly Page Posts Frequency Distribution - 21+', '28 Days Page Posts Frequency Distribution - 2', '28 Days Page Posts Frequency Distribution - 3', '28 Days Page Posts Frequency Distribution - 4', '28 Days Page Posts Frequency Distribution - 5', '28 Days Page Posts Frequency Distribution - 6-10', '28 Days Page Posts Frequency Distribution - 11-20', '28 Days Page Posts Frequency Distribution - 21+', 'Daily Talking About This By Story Type - coupon', 'Daily Talking About This By Story Type - event', 'Daily Talking About This By Story Type - fan', 'Daily Talking About This By Story Type - mention', 'Daily Talking About This By Story Type - other', 'Daily Talking About This By Story Type - page post', 'Daily Talking About This By Story Type - question', 'Daily Talking About This By Story Type - user post', 'Weekly Talking About This By Story Type - coupon', 'Weekly Talking About This By Story Type - event', 'Weekly Talking About This By Story Type - fan', 'Weekly Talking About This By Story Type - mention', 'Weekly Talking About This By Story Type - other', 'Weekly Talking About This By Story Type - page post', 'Weekly Talking About This By Story Type - question', 'Weekly Talking About This By Story Type - user post', '28 Days Talking About This By Story Type - coupon', '28 Days Talking About This By Story Type - event', '28 Days Talking About This By Story Type - fan', '28 Days Talking About This By Story Type - mention', '28 Days Talking About This By Story Type - other', '28 Days Talking About This By Story Type - page post', '28 Days Talking About This By Story Type - question', '28 Days Talking About This By Story Type - user post', 'Daily Page Stories By Story Type - coupon', 'Daily Page Stories By Story Type - event', 'Daily Page Stories By Story Type - fan', 'Daily Page Stories By Story Type - mention', 'Daily Page Stories ...

# %% [markdown]
# Finding categorical columns

# %%
cat_col=[]
for col in df.columns:
  if(df[col].dtypes == 'object'):
    cat_col.append(col)

print(cat_col)
# Out:
# ['Date', 'Lifetime Total Likes', 'Daily New Likes', 'Daily Unlikes', 'Daily Page Engaged Users', 'Weekly Page Engaged Users', '28 Days Page Engaged Users', 'Daily Total Reach', 'Weekly Total Reach', '28 Days Total Reach', 'Daily Organic Reach', 'Weekly Organic Reach', '28 Days Organic Reach', 'Daily Paid Reach', 'Weekly Paid Reach', '28 Days Paid Reach', 'Daily Viral Reach', 'Weekly Viral Reach', '28 Days Viral Reach', 'Daily Total Impressions', 'Weekly Total Impressions', '28 Days Total Impressions', 'Daily Organic impressions', 'Weekly Organic impressions', '28 Days Organic impressions', 'Daily Paid Impressions', 'Weekly Paid Impressions', '28 Days Paid Impressions', 'Daily Viral impressions', 'Weekly Viral impressions', '28 Days Viral impressions', 'Daily Logged-in Page Views', 'Weekly Logged-in Page Views', 'Daily Logged-in Page Views.1', 'Weekly Logged-in Page Views.1', 'Daily Reach Of Page Posts', 'Weekly Reach Of Page Posts', '28 Days Reach Of Page Posts', 'Daily Organic Reach of Page posts', 'Weekly Organic Reach of Page posts', '28 Days Organic Reach of Page posts', 'Daily Paid Reach of Page posts', 'Weekly Paid Reach of Page posts', '28 Days Paid Reach of Page posts', 'Daily Viral Reach Of Page Posts', 'Weekly Viral Reach Of Page Posts', '28 Days Viral Reach Of Page Posts', 'Daily Total Impressions of your posts', 'Weekly Total Impressions of your posts', '28 Days Total Impressions of your posts', 'Daily Organic impressions of your posts', 'Weekly Organic impressions of your posts', '28 Days Organic impressions of your posts', 'Daily Paid impressions of your posts', 'Weekly Paid impressions of your posts', '28 Days Paid impressions of your posts', 'Daily Viral Impressions Of Your Posts', 'Weekly Viral Impressions Of Your Posts', '28 Days Viral Impressions Of Your Posts', 'Daily Total Consumers', 'Weekly Total Consumers', '28 Days Total Consumers', 'Daily Page Consumptions', 'Weekly Page Consumptions', '28 Days Page Consumptions', 'Daily Negative Feedback', 'Weekly Negative Feedback', '28 Days Negative Feedback', 'Daily Negative Feedback From Users', 'Weekly Negative Feedback From Users', '28 Days Negative Feedback From Users', 'Daily Total Check-Ins', 'Weekly Total Check-Ins', '28 Days Total Check-Ins', 'Daily Total Check-Ins.1', 'Weekly Total Check-Ins.1', '28 Days Total Check-Ins.1', 'Daily Total Check-Ins Using Mobile Devices', 'Weekly Total Check-Ins Using Mobile Devices', '28 Days Total Check-Ins Using Mobile Devices', 'Daily Total Check-Ins Using Mobile Devices.1', 'Weekly Total Check-Ins Using Mobile Devices.1', '28 Days Total Check-Ins Using Mobile Devices.1', 'Daily Total Organic Views', 'Weekly Total Organic Views', '28 Days Total Organic Views', 'Daily Total Promoted Views', 'Weekly Total Promoted Views', '28 Days Total Promoted Views', 'Daily Total Organic 30-Second Views', 'Weekly Total Organic 30-Second Views', '28 Days Total Organic 30-Second Views', 'Daily Paid 30-Second Views', 'Weekly Paid 30-Second Views', '28 Days Paid 30-Second Views', 'Daily Total Video Views', 'Weekly Total Video Views', '28 Days Total Video Views', 'Daily Total Auto-Played Views', 'Weekly Total Auto-Played Views', '28 Days Total Auto-Played Views', 'Daily Total Clicked Views', 'Weekly Total Clicked Views', '28 Days Total Clicked Views', 'Daily Video Repeats', 'Weekly Video Repeats', '28 Days Video Repeats', 'Daily Total Unique Video Views', 'Weekly Total Unique Video Views', '28 Days Total Unique Video Views', 'Daily Total 30-Second Views', 'Weekly Total 30-Second Views', '28 Days Total 30-Second Views', 'Daily Auto-Played 30-Second Views', 'Weekly Auto-Played 30-Second Views', '28 Days Auto-Played 30-Second Views', 'Daily Total Clicked 30-Second Views', 'Weekly Total Clicked 30-Second Views', '28 Days Total Clicked 30-Second Views', 'Daily Total 30-Second Repeats', 'Weekly Total 30-Second Repeats', '28 Days Total 30-Second Repeats', 'Daily Total Unique 30-Second Views', 'Weekly Total Unique 30-Second Views', '28 Days Total Un ...

# %%
df.isnull().sum()
# Out:
# Date                                                                        1
# Lifetime Total Likes                                                        0
# Daily New Likes                                                             1
# Daily Unlikes                                                               8
# Daily Page Engaged Users                                                    0
#                                                                            ..
# Weekly Total web site click count per Page by age and gender - &lt;13.M     1
# Weekly Total web site click count per Page by age and gender - &lt;13.U     1
# Weekly Total web site click count per Page by age and gender - UNKNOWN.F    1
# Weekly Total web site click count per Page by age and gender - UNKNOWN.M    1
# Weekly Total web site click count per Page by age and gender - UNKNOWN.U    1
# Length: 1468, dtype: int64

# %%
df.shape
# Out:
# (29, 1468)

# %%
Twitter_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5952 entries, 0 to 5951
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   A_follower_count     5952 non-null   int64
#  1   A_following_count    5952 non-null   int64
#  2   A_listed_count       5952 non-null   int64
#  3   A_mentions_received  5952 non-null   float64
#  4   A_retweets_received  5952 non-null   float64
#  5   A_mentions_sent      5952 non-null   float64
#  6   A_retweets_sent      5952 non-null   float64
#  7   A_posts              5952 non-null   float64
#  8   A_network_feature_1  5952 non-null   int64
#  9   A_network_feature_2  5952 non-null   float64
#  10  A_network_feature_3  5952 non-null   float64
#  11  B_follower_count     5952 non-null   int64
#  12  B_following_count    5952 non-null   int64
#  13  B_listed_count       5952 non-null   int64
#  14  B_mentions_received  5952 non-null   float64
#  15  B_retweets_received  5952 non-null   float64
#  16  B_mentions_sent      5952 non-null   float64
#  17  B_retweets_sent      5952 non-null   float64
#  18  B_posts              5952 non-null   float64
#  19  B_network_feature_1  5952 non-null   int64
#  20  B_network_feature_2  5952 non-null   float64
#  21  B_network_feature_3  5952 non-null   float64
# dtypes: float64(14), int64(8)
# memory usage: 1023.1 KB

# %%
Twitter_Train.describe()
# Out:
#        A_follower_count  A_following_count  A_listed_count  \
# count      5.952000e+03        5952.000000     5952.000000
# mean       7.087657e+05       15816.745128     6230.993952
# std        2.085302e+06       57157.375055    17367.157429
# min        2.000000e+01           0.000000        0.000000
# 25%        3.741000e+03         337.000000      103.000000
# 50%        5.445300e+04         904.000000     1062.000000
# 75%        4.885530e+05        3256.000000     6820.000000
# max        3.654319e+07      550744.000000   549144.000000
#
#        A_mentions_received  A_retweets_received  A_mentions_sent  \
# count         5.952000e+03          5952.000000      5952.000000
# mean          2.610369e+03           999.216821         6.376236
# std           2.825216e+04         10585.986980        10.699849
# min           1.005034e-01             0.100503         0.100503
# 25%           4.124998e+00             0.933434         0.362150
# 50%           5.513727e+01            14.161040         2.299666
# 75%           3.882108e+02           128.707883         6.849227
# max           1.145219e+06        435825.874241        96.678732
#
#        A_retweets_sent      A_posts  A_network_feature_1  A_network_feature_2  \
# count      5952.000000  5952.000000          5952.000000          5952.000000
# mean          1.138599     9.665749          5170.248488            84.492860
# std           1.999076    19.999954         28305.471154            98.005953
# min           0.100503     0.100503             0.000000             0.000000
# 25%           0.100503     0.867285            15.000000            17.914359
# 50%           0.349327     3.398350           206.000000            55.483333
# 75%           1.320681    10.746838          1637.000000           117.098039
# max          26.873251   193.072418        920838.000000          1171.333333
#
#        ...  B_following_count  B_listed_count  B_mentions_received  \
# count  ...        5952.000000     5952.000000         5.952000e+03
# mean   ...       14841.442372     6117.086190         2.606966e+03
# std    ...       56158.272513    16341.230784         2.462033e+04
# min    ...           0.000000        0.000000         1.005034e-01
# 25%    ...         331.000000      103.000000         4.237052e+00
# 50%    ...         900.000000      930.500000         4.807372e+01
# 75%    ...        3115.000000     6734.000000         3.743699e+02
# max    ...      664324.000000   549144.000000         1.145219e+06
#
#        B_retweets_received  B_mentions_sent  B_retweets_sent      B_posts  \
# count          5952.000000      5952.000000      5952.000000  5952.000000
# mean           1010.544365         6.199827         1.156266     9.016867
# std            9170.174893        10.320966         1.978121    17.658846
# min               0.100503         0.100503         0.100503     0.100503
# 25%               0.932458         0.362150         0.100503     0.847662
# 50%              13.194818         2.324112         0.354379     3.342999
# 75%             106.676389         6.825165         1.337915    10.691878
# max          435825.874241        96.678732        26.873251   193.072418
#
#        B_network_feature_1  B_network_feature_2  B_network_feature_3
# count          5952.000000          5952.000000          5952.000000
# mean           5384.529906            88.190013          4104.448241
# std           27497.488106           145.716530          8042.921162
# min               0.000000             0.000000             0.000000
# 25%              15.000000            17.731521          1230.512781
# 50%             188.000000            57.888000          2381.466667
# 75%            1323.000000           120.195059          4544.541667
# max          920838.000000          8111.750000        464349.250000
#
# [8 rows x 22 columns]

# %%
print("Any missing values in the dataset:", Twitter_Train.isnull().values.any())
# Out:
# Any missing values in the dataset: False

# %%
# Testing the correlation

correlationA = Twitter_Train .iloc[:,1:12].corr(method = 'pearson')
correlationA

ax = sns.heatmap(
    correlationA,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n = 200),
    square=True,
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
# Out:
# [Text(0.5, 0, 'A_following_count'),
#  Text(1.5, 0, 'A_listed_count'),
#  Text(2.5, 0, 'A_mentions_received'),
#  Text(3.5, 0, 'A_retweets_received'),
#  Text(4.5, 0, 'A_mentions_sent'),
#  Text(5.5, 0, 'A_retweets_sent'),
#  Text(6.5, 0, 'A_posts'),
#  Text(7.5, 0, 'A_network_feature_1'),
#  Text(8.5, 0, 'A_network_feature_2'),
#  Text(9.5, 0, 'A_network_feature_3'),
#  Text(10.5, 0, 'B_follower_count')]

# %%
correlationB = Twitter_Train.iloc[:,12:23].corr(method='pearson')
correlationB

ax = sns.heatmap(
    correlationB,
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n = 200),
    square=True,
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
# Out:
# [Text(0.5, 0, 'B_following_count'),
#  Text(1.5, 0, 'B_listed_count'),
#  Text(2.5, 0, 'B_mentions_received'),
#  Text(3.5, 0, 'B_retweets_received'),
#  Text(4.5, 0, 'B_mentions_sent'),
#  Text(5.5, 0, 'B_retweets_sent'),
#  Text(6.5, 0, 'B_posts'),
#  Text(7.5, 0, 'B_network_feature_1'),
#  Text(8.5, 0, 'B_network_feature_2'),
#  Text(9.5, 0, 'B_network_feature_3')]

# %% [markdown]
# CONCLUSION:
#
# In social media analytics, high precision means that an algorithm returned more relevant results than irrelevant, while high recall means that an algorithm returned most of the relevant results. there is a 79% precision that there are more relevant values and a 79% recall that most of the relevant values are included in our model.
